# %% [markdown]
# # Importing Libraries and Loading data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as an

# %%
data=pd.read_csv("E:/Black_Friday_Sale.csv")
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %% [markdown]
# # Checking Null values

# %%
data.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
data.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %% [markdown]
# # show all columns

# %%
a=data.columns
a
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %% [markdown]
# # plot scatter for first 100 rows for 2 required columns

# %%
data[0:100]
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0   1000001  P00069042      F   0-17          10             A
# 1   1000001  P00248942      F   0-17          10             A
# 2   1000001  P00087842      F   0-17          10             A
# 3   1000001  P00085442      F   0-17          10             A
# 4   1000002  P00285442      M    55+          16             C
# ..      ...        ...    ...    ...         ...           ...
# 95  1000019  P00251642      M   0-17          10             A
# 96  1000019  P00244842      M   0-17          10             A
# 97  1000021  P00220242      M  18-25          16             B
# 98  1000022  P00351142      M  18-25          15             A
# 99  1000022  P00213242      M  18-25          15             A
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# ...

# %%
data.plot(kind='scatter', 
             x='Age', 
             y='Occupation', 
             figsize=(7, 4));

# %% [markdown]
# # plot histogram for all applicable columns

# %%
plt.hist(data["Age"])
# Out:
# (array([ 15102.,  21504.,      0., 219587.,      0.,  45701.,  38501.,
#              0., 110013.,  99660.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["Product_ID"])
# Out:
# (array([157014., 115809.,  85393.,  66807.,  47602.,  30588.,  21587.,
#          13942.,   5611.,   5715.]),
#  array([   0.,  363.,  726., 1089., 1452., 1815., 2178., 2541., 2904.,
#         3267., 3630.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # transpose first 10 rows

# %%
data[0:10].T
# Out:
#                                     0          1          2          3  \
# User_ID                       1000001    1000001    1000001    1000001
# Product_ID                  P00069042  P00248942  P00087842  P00085442
# Gender                              F          F          F          F
# Age                              0-17       0-17       0-17       0-17
# Occupation                         10         10         10         10
# City_Category                       A          A          A          A
# Stay_In_Current_City_Years          2          2          2          2
# Marital_Status                      0          0          0          0
# Product_Category_1                  3          1         12         12
# Product_Category_2                NaN        6.0        NaN       14.0
# Product_Category_3                NaN       14.0        NaN        NaN
# Purchase                         8370      15200       1422       1057
#
# ...

# %% [markdown]
# # sort the dataframe based on any applicable numeric value and override in actual data (hint: you can use sort_values())

# %%
data.sort_values("Age")
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001  P00069042      F  0-17          10             A
# 48932   1001499  P00100442      M  0-17          10             C
# 48933   1001499  P00255842      M  0-17          10             C
# 48934   1001499  P00070342      M  0-17          10             C
# 48935   1001499  P00275542      M  0-17          10             C
# ...         ...        ...    ...   ...         ...           ...
# 47161   1001252  P00357242      M   55+          13             C
# 47162   1001252  P00322942      M   55+          13             C
# 114629  1005686  P00101942      M   55+          16             A
# 188070  1005033  P00112342      F   55+          13             C
# 132077  1002280  P00004142      M   55+           6             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# # make a copy of dataframe now

# %%
a=data.copy()
a
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# # transpose copied dataframe

# %%
a.T
# Out:
#                                0          1          2          3       \
# User_ID                       1000001    1000001    1000001    1000001
# Product_ID                  P00069042  P00248942  P00087842  P00085442
# Gender                              F          F          F          F
# Age                              0-17       0-17       0-17       0-17
# Occupation                         10         10         10         10
# City_Category                       A          A          A          A
# Stay_In_Current_City_Years          2          2          2          2
# Marital_Status                      0          0          0          0
# Product_Category_1                  3          1         12         12
# Product_Category_2                NaN        6.0        NaN       14.0
# Product_Category_3                NaN       14.0        NaN        NaN
# Purchase                         8370      15200       1422       1057
#
# ...

# %% [markdown]
# # drop unnecessary columns from copied dataframe

# %%
data=data.drop("Gender",axis=1)
data
# Out:
#         User_ID Product_ID    Age  Occupation City_Category  \
# 0       1000001  P00069042   0-17          10             A
# 1       1000001  P00248942   0-17          10             A
# 2       1000001  P00087842   0-17          10             A
# 3       1000001  P00085442   0-17          10             A
# 4       1000002  P00285442    55+          16             C
# ...         ...        ...    ...         ...           ...
# 550063  1006033  P00372445  51-55          13             B
# 550064  1006035  P00375436  26-35           1             C
# 550065  1006036  P00375436  26-35          15             B
# 550066  1006038  P00375436    55+           1             C
# 550067  1006039  P00371644  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
data=data.drop("Occupation",axis=1)
data
# Out:
#         User_ID Product_ID    Age City_Category Stay_In_Current_City_Years  \
# 0       1000001  P00069042   0-17             A                          2
# 1       1000001  P00248942   0-17             A                          2
# 2       1000001  P00087842   0-17             A                          2
# 3       1000001  P00085442   0-17             A                          2
# 4       1000002  P00285442    55+             C                         4+
# ...         ...        ...    ...           ...                        ...
# 550063  1006033  P00372445  51-55             B                          1
# 550064  1006035  P00375436  26-35             C                          3
# 550065  1006036  P00375436  26-35             B                         4+
# 550066  1006038  P00375436    55+             C                          2
# 550067  1006039  P00371644  46-50             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %% [markdown]
# # count the number of values for each column

# %%
data.count()
# Out:
# User_ID                       550068
# Product_ID                    550068
# Age                           550068
# City_Category                 550068
# Stay_In_Current_City_Years    550068
# Marital_Status                550068
# Product_Category_1            550068
# Product_Category_2            376430
# Product_Category_3            166821
# Purchase                      550068
# dtype: int64

# %% [markdown]
# # check length of full dataset

# %%
len(data)
# Out:
# 550068

# %%
data["Age"].count()
# Out:
# np.int64(550068)

# %% [markdown]
# # find datatypes of columns

# %%
data.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Age                            object
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %% [markdown]
# # check for missing data and fill it with length of dataframe

# %%
data.fillna(len(data))
# Out:
#         User_ID Product_ID    Age City_Category Stay_In_Current_City_Years  \
# 0       1000001  P00069042   0-17             A                          2
# 1       1000001  P00248942   0-17             A                          2
# 2       1000001  P00087842   0-17             A                          2
# 3       1000001  P00085442   0-17             A                          2
# 4       1000002  P00285442    55+             C                         4+
# ...         ...        ...    ...           ...                        ...
# 550063  1006033  P00372445  51-55             B                          1
# 550064  1006035  P00375436  26-35             C                          3
# 550065  1006036  P00375436  26-35             B                         4+
# 550066  1006038  P00375436    55+             C                          2
# 550067  1006039  P00371644  46-50             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %% [markdown]
# # Export copied dataframe

# %%
a.to_csv("exported-black_Friday_sale.csv", index=False)
a
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
exported_black_Friday = pd.read_csv("exported-black_Friday_sale.csv")
exported_black_Friday
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# # import exported data

# %%
a
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# # Use RandomForestRegressor and split training and testing data and fit the data to train the model

# %%
#create x (all the feature coloum)
X=a.drop("Age",axis=1)
# create y  (the Age coloum)
y=a["Age"]

# %%
a=a.drop("Age",axis=1)
a
# Out:
#         User_ID Product_ID Gender  Occupation City_Category  \
# 0       1000001  P00069042      F          10             A
# 1       1000001  P00248942      F          10             A
# 2       1000001  P00087842      F          10             A
# 3       1000001  P00085442      F          10             A
# 4       1000002  P00285442      M          16             C
# ...         ...        ...    ...         ...           ...
# 550063  1006033  P00372445      M          13             B
# 550064  1006035  P00375436      F           1             C
# 550065  1006036  P00375436      F          15             B
# 550066  1006038  P00375436      F           1             C
# 550067  1006039  P00371644      F           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
a=a.drop("City_Category",axis=1)
a
# Out:
#         User_ID Product_ID Gender  Occupation Stay_In_Current_City_Years  \
# 0       1000001  P00069042      F          10                          2
# 1       1000001  P00248942      F          10                          2
# 2       1000001  P00087842      F          10                          2
# 3       1000001  P00085442      F          10                          2
# 4       1000002  P00285442      M          16                         4+
# ...         ...        ...    ...         ...                        ...
# 550063  1006033  P00372445      M          13                          1
# 550064  1006035  P00375436      F           1                          3
# 550065  1006036  P00375436      F          15                         4+
# 550066  1006038  P00375436      F           1                          2
# 550067  1006039  P00371644      F           0                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
a=a.drop("Stay_In_Current_City_Years",axis=1)
a
# Out:
#         User_ID Product_ID Gender  Occupation  Marital_Status  \
# 0       1000001  P00069042      F          10               0
# 1       1000001  P00248942      F          10               0
# 2       1000001  P00087842      F          10               0
# 3       1000001  P00085442      F          10               0
# 4       1000002  P00285442      M          16               0
# ...         ...        ...    ...         ...             ...
# 550063  1006033  P00372445      M          13               1
# 550064  1006035  P00375436      F           1               0
# 550065  1006036  P00375436      F          15               1
# 550066  1006038  P00375436      F           1               0
# 550067  1006039  P00371644      F           0               1
#
#         Product_Category_1  Product_Category_2  Product_Category_3  Purchase
# 0                        3                 NaN                 NaN      8370
# ...

# %%
#split the data into training and test sets
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y)
# View the data shapes
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((412551, 11), (137517, 11), (412551,), (137517,))

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(a['Gender'])
a['Gender']=le.transform(a['Gender'])
a['Gender'].unique()
a
# Out:
#         User_ID Product_ID  Gender  Occupation  Marital_Status  \
# 0       1000001  P00069042       0          10               0
# 1       1000001  P00248942       0          10               0
# 2       1000001  P00087842       0          10               0
# 3       1000001  P00085442       0          10               0
# 4       1000002  P00285442       1          16               0
# ...         ...        ...     ...         ...             ...
# 550063  1006033  P00372445       1          13               1
# 550064  1006035  P00375436       0           1               0
# 550065  1006036  P00375436       0          15               1
# 550066  1006038  P00375436       0           1               0
# 550067  1006039  P00371644       0           0               1
#
#         Product_Category_1  Product_Category_2  Product_Category_3  Purchase
# 0                        3                 NaN                 NaN      8370
# ...

# %%
a=a.drop("Product_ID",axis=1)
a
# Out:
#         User_ID  Gender  Occupation  Marital_Status  Product_Category_1  \
# 0       1000001       0          10               0                   3
# 1       1000001       0          10               0                   1
# 2       1000001       0          10               0                  12
# 3       1000001       0          10               0                  12
# 4       1000002       1          16               0                   8
# ...         ...     ...         ...             ...                 ...
# 550063  1006033       1          13               1                  20
# 550064  1006035       0           1               0                  20
# 550065  1006036       0          15               1                  20
# 550066  1006038       0           1               0                  20
# 550067  1006039       0           0               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# ...

# %%
len(a)
# Out:
# 550068

# %%
a.dtypes
# Out:
# User_ID                 int64
# Gender                  int64
# Occupation              int64
# Marital_Status          int64
# Product_Category_1      int64
# Product_Category_2    float64
# Product_Category_3    float64
# Purchase                int64
# dtype: object

# %%
'''from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(a['City_Category'])
a['City_Category']=le.transform(a['City_Category'])
a['City_Category'].unique()
a'''
# Out:
# "from sklearn.preprocessing import LabelEncoder\nle = LabelEncoder()\nle.fit(a['City_Category'])\na['City_Category']=le.transform(a['City_Category'])\na['City_Category'].unique()\na"

# %%
a.fillna(len(a))
# Out:
#         User_ID  Gender  Occupation  Marital_Status  Product_Category_1  \
# 0       1000001       0          10               0                   3
# 1       1000001       0          10               0                   1
# 2       1000001       0          10               0                  12
# 3       1000001       0          10               0                  12
# 4       1000002       1          16               0                   8
# ...         ...     ...         ...             ...                 ...
# 550063  1006033       1          13               1                  20
# 550064  1006035       0           1               0                  20
# 550065  1006036       0          15               1                  20
# 550066  1006038       0           1               0                  20
# 550067  1006039       0           0               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# ...

# %%
a.dtypes
# Out:
# User_ID                 int64
# Gender                  int64
# Occupation              int64
# Marital_Status          int64
# Product_Category_1      int64
# Product_Category_2    float64
# Product_Category_3    float64
# Purchase                int64
# dtype: object

# %%
#create x (all the feature coloum)
X=a.drop("Gender",axis=1)
# create y  (the Age coloum)
y=a["Gender"]

# %%
#split the data into training and test sets
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y)
# View the data shapes
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((412551, 7), (137517, 7), (412551,), (137517,))

# %%
y_preds = model.predict(X_test)
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()

# %%
y_preds=model.predict(X_test)
y_preds
# Out:
# array([1., 1., 1., ..., 1., 1., 0.])

# %%
model.score(X_train,y_train)
# Out:
# 0.9981673574992139

# %%
model.score(X_test,y_test)
# Out:
# 0.9882889275874422
